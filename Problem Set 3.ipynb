# %% [markdown]
# # Question 1

# %%
#step 1
import pandas as pd

#step 2,3
users = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user",sep='|')

#step 4
users.groupby('occupation').agg({'age':'mean'})
# Out:
#                      age
# occupation
# administrator  38.746835
# artist         31.392857
# doctor         43.571429
# educator       42.010526
# engineer       36.388060
# entertainment  29.222222
# executive      38.718750
# healthcare     41.562500
# homemaker      32.571429
# lawyer         36.750000
# librarian      40.000000
# marketing      37.615385
# none           26.555556
# other          34.523810
# programmer     33.121212
# retired        63.071429
# salesman       35.666667
# scientist      35.548387
# student        22.081633
# technician     33.148148
# writer         36.311111

# %%
#step 5

# %%
#step 6 max
users.groupby('occupation').agg({'age':'max'})
# Out:
#                age
# occupation
# administrator   70
# artist          48
# doctor          64
# educator        63
# engineer        70
# entertainment   50
# executive       69
# healthcare      62
# homemaker       50
# lawyer          53
# librarian       69
# marketing       55
# none            55
# other           64
# programmer      63
# retired         73
# salesman        66
# scientist       55
# student         42
# technician      55
# writer          60

# %%
#step 6 min
users.groupby('occupation').agg({'age':'min'})
# Out:
#                age
# occupation
# administrator   21
# artist          19
# doctor          28
# educator        23
# engineer        22
# entertainment   15
# executive       22
# healthcare      22
# homemaker       20
# lawyer          21
# librarian       23
# marketing       24
# none            11
# other           13
# programmer      20
# retired         51
# salesman        18
# scientist       23
# student          7
# technician      21
# writer          18

# %%
#step 7
users.groupby(['occupation','gender']).agg({'age':'mean'})
# Out:
#                             age
# occupation    gender
# administrator F       40.638889
#               M       37.162791
# artist        F       30.307692
#               M       32.333333
# doctor        M       43.571429
# educator      F       39.115385
#               M       43.101449
# engineer      F       29.500000
#               M       36.600000
# entertainment F       31.000000
#               M       29.000000
# executive     F       44.000000
#               M       38.172414
# healthcare    F       39.818182
#               M       45.400000
# homemaker     F       34.166667
#               M       23.000000
# lawyer        F       39.500000
#               M       36.200000
# librarian     F       40.000000
#               M       40.000000
# marketing     F       37.200000
#               M       37.875000
# none          F       36.500000
#               M       18.600000
# other         F       35.472222
#               M       34.028986
# ...

# %%
#step 8
users2 = users.groupby(['occupation','gender']).agg({'gender':'count'}).rename(columns={'gender': 'gender_count'})

users2['percent'] = (users2['gender_count'] / users2.groupby('occupation')['gender_count'].transform('sum'))*100

users2
# Out:
#                       gender_count     percent
# occupation    gender
# administrator F                 36   45.569620
#               M                 43   54.430380
# artist        F                 13   46.428571
#               M                 15   53.571429
# doctor        M                  7  100.000000
# educator      F                 26   27.368421
#               M                 69   72.631579
# engineer      F                  2    2.985075
#               M                 65   97.014925
# entertainment F                  2   11.111111
#               M                 16   88.888889
# executive     F                  3    9.375000
#               M                 29   90.625000
# healthcare    F                 11   68.750000
#               M                  5   31.250000
# homemaker     F                  6   85.714286
#               M                  1   14.285714
# lawyer        F                  2   16.666667
# ...

# %% [markdown]
# # Question 2

# %%
#step 1
import pandas as pd

#step 2,3
euro12 = pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv")
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 0                     0  ...          13                 81.3%         41
# 1                     0  ...           9                 60.1%         53
# 2                     0  ...          10                 66.7%         25
#
# ...

# %%
#step 4
euro12['Goals']
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %%
#step 5
euro12['Team'].count()
# Out:
# 16

# %%
#step 6
len(euro12.columns)
# Out:
# 35

# %%
#step 7
discipline = euro12[['Team','Yellow Cards','Red Cards']].copy()
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %%
#step 8
discipline.sort_values(by=['Red Cards', 'Yellow Cards'])
# Out:
#                    Team  Yellow Cards  Red Cards
# 2               Denmark             4          0
# 5               Germany             4          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 4                France             6          0
# 12               Russia             6          0
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 0               Croatia             9          0
# 13                Spain            11          0
# 10             Portugal            12          0
# 7                 Italy            16          0
# 11  Republic of Ireland             6          1
# 9                Poland             7          1
# 6                Greece             9          1

# %%
#step 9
euro12.groupby('Team').agg({'Yellow Cards':'mean'})
# Out:
#                      Yellow Cards
# Team
# Croatia                       9.0
# Czech Republic                7.0
# Denmark                       4.0
# England                       5.0
# France                        6.0
# Germany                       4.0
# Greece                        9.0
# Italy                        16.0
# Netherlands                   5.0
# Poland                        7.0
# Portugal                     12.0
# Republic of Ireland           6.0
# Russia                        6.0
# Spain                        11.0
# Sweden                        7.0
# Ukraine                       5.0

# %%
#step 10
euro12[euro12['Goals']>6]
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany     10               32                32             47.8%
# 13    Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 13            16.0%                         100             0              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                      0  ...          10                 62.6%         63
# 13                     0  ...          15                 93.8%        102
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5              49        12             4          0       15        15
# 13             83        19            11          0       17        17
#
#     Players Used
# 5             17
# 13            18
#
# ...

# %%
#step 11
euro12[euro12['Team'].str.startswith('G')]
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany     10               32                32             47.8%
# 6   Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.6%                          80             2              1
# 6            19.2%                          32             1              1
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                     0  ...          10                 62.6%         63
# 6                     1  ...          13                 65.1%         67
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5             49        12             4          0       15        15
# 6             48        12             9          1       12        12
#
#    Players Used
# 5            17
# 6            20
#
# [2 rows x 35 columns]

# %%
#step 13
euro12.iloc[:, 0:7]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
#step 13
euro12.iloc[:, len(euro12.columns)-3:len(euro12.columns)]
# Out:
#     Subs on  Subs off  Players Used
# 0         9         9            16
# 1        11        11            19
# 2         7         7            15
# 3        11        11            16
# 4        11        11            19
# 5        15        15            17
# 6        12        12            20
# 7        18        18            19
# 8         7         7            15
# 9         7         7            17
# 10       14        14            16
# 11       10        10            17
# 12        7         7            16
# 13       17        17            18
# 14        9         9            18
# 15        9         9            18

# %%
#step 14
euro1214 = euro12[euro12['Team'].isin(['England','Italy','Russia'])].copy()
euro1214[['Team','Shooting Accuracy']]
# Out:
#        Team Shooting Accuracy
# 3   England             50.0%
# 7     Italy             43.0%
# 12   Russia             22.5%

# %% [markdown]
# # Question 3

# %%
import pandas as pd
import numpy as np

firstSeries = np.random.randint(1,5,size=(100))
secondSeries = np.random.randint(1,4,size=(100))
thirdSeries = np.random.randint(10000,30001,size=(100))

df = pd.DataFrame({'bedrs':firstSeries,'bathrs':secondSeries,'price_sqr_meter':thirdSeries})

bigcolumn = pd.DataFrame({'bigcolumn':firstSeries+secondSeries+thirdSeries})

bigcolumn.reset_index(drop = True)
# Out:
#     bigcolumn
# 0       18711
# 1       28652
# 2       22063
# 3       19206
# 4       23228
# ..        ...
# 95      23940
# 96      27601
# 97      29542
# 98      16838
# 99      12844
#
# [100 rows x 1 columns]

# %% [markdown]
# # Question 4

# %%
import pandas as pd

data = pd.read_csv("wind.txt")

data
# Out:
#      Yr Mo Dy   RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL
# 0     61  1  1 15.04 14.96 13.17  9.29   NaN  9.87 1...
# 1     61  1  2 14.71   NaN 10.83  6.50 12.62  7.67 1...
# 2     61  1  3 18.50 16.88 12.33 10.13 11.17  6.17 1...
# 3     61  1  4 10.58  6.63 11.75  4.58  4.54  2.88  ...
# 4     61  1  5 13.33 13.25 11.42  6.17 10.71  8.21 1...
# ...                                                 ...
# 6569  78 12 27 17.58 16.96 17.62  8.08 13.21 11.67 1...
# 6570  78 12 28 13.21  5.46 13.46  5.00  8.12  9.42 1...
# 6571  78 12 29 14.00 10.29 14.42  8.71  9.71 10.54 1...
# 6572  78 12 30 18.50 14.04 21.29  9.13 12.75  9.71 1...
# 6573  78 12 31 20.33 17.41 27.29  9.59 12.08 10.13 1...
#
# [6574 rows x 1 columns]

# %% [markdown]
# # Question 5

# %%
#step 1, 2
import pandas as pd

chipo = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv", sep = '\t')
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
#step 4
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
#step 5
chipo['order_id'].count()
# Out:
# 4622

# %%
#step 6
len(chipo.columns)
# Out:
# 5

# %%
#step 7
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
#step 8

# %%
#step 9, 10
chipo2 = chipo.groupby('item_name').agg({'item_name':'count'}).rename(columns={'item_name': 'item_count'})

chipo3 = chipo2.sort_values(by = 'item_count', ascending = False)

chipo3.head(1)
# Out:
#               item_count
# item_name
# Chicken Bowl         726

# %%
#step 11
chipo2 = chipo.groupby('choice_description').agg({'choice_description':'count'}).rename(columns={'choice_description': 'choice_count'})

chipo3 = chipo2.sort_values(by = 'choice_count', ascending = False)

chipo3.head(1)
# Out:
#                     choice_count
# choice_description
# [Diet Coke]                  134

# %%
#step 12
chipo['order_id'].count()
# Out:
# 4622

# %%
#step 13

# %%
#step 14

# %%
#step 15
chipo['order_id'].max()
# Out:
# 1834

# %%
#step 16

# %%
#step 17
chipo['item_name'].nunique()
# Out:
# 50

# %% [markdown]
# # Question 6

# %%
import matplotlib.pyplot as pp
import pandas as pd
import numpy as np

marry=pd.read_csv("us-marriages-divorces-1867-2014.csv")
#marryM=pd.read_csv("us-marriages-divorces-1867-2014.csv", usecols=[1])
#marryD=pd.read_csv("us-marriages-divorces-1867-2014.csv", usecols=[2])



nMarryYear = np.array(marry['Year'])
nMarryM = np.array(marry['Marriages']/marry['Population'])
nMarryD = np.array(marry['Divorces']/marry['Population'])

pp.plot(nMarryM,nMarryYear)
pp.plot(nMarryD,nMarryYear)
pp.legend(['Marriage per Capita','Divorce per Capita'])
pp.xlabel('Marriages / Divorces per Capita')
pp.ylabel('Year')
pp.title('Marriages / Divorces per Capita for Each Year')
# Out:
# Text(0.5, 1.0, 'Marriages / Divorces per Capita for Each Year')

# %% [markdown]
# # Question 7

# %%
import matplotlib.pyplot as pp
import pandas as pd
import numpy as np

marry=pd.read_csv("us-marriages-divorces-1867-2014.csv")
marryYear = marry[marry['Year'].isin([1900,1950,2000])].copy()

marryYear['MarriageperCapita'] = marryYear['Marriages']/marryYear['Population']
marryYear['DivorceperCapita'] = marryYear['Divorces']/marryYear['Population']

marryYear2 = marryYear[['Year','MarriageperCapita','DivorceperCapita']]

marryYear2 = marryYear2.set_index(['Year'])
#xyz = np.arange(len(nMarryYear))

marryYear2.plot(kind='bar')

pp.legend(['Marriage per Capita','Divorce per Capita'])
pp.ylabel('Marriages / Divorces per Capita')
pp.xlabel('Year')
pp.title('Marriages / Divorces per Capita in 1900, 1950 and 2000')
# Out:
# Text(0.5, 1.0, 'Marriages / Divorces per Capita in 1900, 1950 and 2000')

# %% [markdown]
# # Question 8

# %%
import matplotlib.pyplot as pp
import pandas as pd
import numpy as np

actors=pd.read_csv("actor_kill_counts.csv")

actors2 = actors.sort_values('Count')

actors3 = actors2.set_index('Actor')

actors3.plot(kind='barh')

pp.legend(['Actor'])
pp.ylabel('Killcount')
pp.xlabel('Actor')
pp.title('Marriages / Divorces per Capita in 1900, 1950 and 2000')
# Out:
# Text(0.5, 1.0, 'Marriages / Divorces per Capita in 1900, 1950 and 2000')

# %% [markdown]
# # Question 9

# %%
import matplotlib.pyplot as pp
import pandas as pd
import numpy as np

deaths=pd.read_csv("roman-emperor-reigns.csv")

deaths2 = deaths[deaths['Cause_of_Death'] == 'Assassinated']

deaths3 = deaths2[['Emperor']]

deaths3.groupby(['Emperor']).Emperor.agg(['count']).rename(columns={'count': 'Count'}).plot(kind='pie', y='Count', figsize=(20, 20))
#deaths3.groupby('Emperor').Emperor.agg(['count']).rename(columns={'count': 'Count'})

#deaths3.groupby(['Emperor']).count().plot(kind='pie', y='Emperor')

#deaths3.plot.pie(y='Count')
pp.legend(loc="upper right")
pp.title('Assassinated Roman Emperors')
# Out:
# Text(0.5, 1.0, 'Assassinated Roman Emperors')

# %% [markdown]
# # Question 10

# %%
import matplotlib.pyplot as pp
import pandas as pd
import numpy as np

revenue=pd.read_csv("arcade-revenue-vs-cs-doctorates.csv")
revenue

#revenue1 =  revenue[['Total Arcade Revenue (billions)','Computer Science Doctorates Awarded (US)']]

revenue.plot.scatter(x = 'Total Arcade Revenue (billions)', y = 'Computer Science Doctorates Awarded (US)', colormap ='inferno', c = 'Year',  sharex=False)

pp.legend(['Year'])
pp.ylabel('Computer Science Doctorates Awarded (US)')
pp.xlabel('Total Arcade Revenue (billions)')
pp.title('Relationship Between Total Arcade Revenue (billions) and Computer Science Doctorates Awarded (US)')
# Out:
# Text(0.5, 1.0, 'Relationship Between Total Arcade Revenue (billions) and Computer Science Doctorates Awarded (US)')
